# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/My Projects/amazon review insight engine/data/Reviews.csv")
df.head()
# Out:
#        Id   ProductId          UserId                            ProfileName  \
# 0    3059  B0005ZWBPC  A32BM1CZ627MVJ                  Ruhama "Bibliophilia"
# 1  317475  B007TJGY5K  A221IYGUANAAL2                        Cheryl L. Clark
# 2  313318  B000FD7C6W  A29LN5V6HPB8TC  Ronald Shepard "Blown Corvette Lover"
# 3   11194  B00213ERI0  A1BJ67411QA0WZ                                     BB
# 4  551458  B004L5NFT8  A3CTUMYWO71U10                         Joan Gottfried
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  2010-05-03
# 1                     1                       1      5  2010-08-06
# 2                     1                       1      5  2011-09-18
# 3                     0                       0      4  2009-09-12
# 4                     0                       1      2  2011-09-30
#
#                               Summary  \
# 0                      Passover treat
# ...

# %%
import os
from transformers.utils import logging as hf_logging

hf_logging.set_verbosity_error()
hf_token = os.getenv("HF_TOKEN")
model = SentenceTransformer("all-MiniLM-L6-v2", token=hf_token or False)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
import os
from transformers.utils import logging as hf_logging

hf_logging.set_verbosity_error()
hf_token = os.getenv("HF_TOKEN")
model = SentenceTransformer("all-MiniLM-L6-v2", token=hf_token or False)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
import os
from transformers.utils import logging as hf_logging

hf_logging.set_verbosity_error()
hf_token = os.getenv("HF_TOKEN")
model = SentenceTransformer("all-MiniLM-L6-v2", token=hf_token or False)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
import os
from transformers.utils import logging as hf_logging

hf_logging.set_verbosity_error()
hf_token = os.getenv("HF_TOKEN")
model = SentenceTransformer("all-MiniLM-L6-v2", token=hf_token or False)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
texts = df["full_text"].tolist()

embeddings = model.encode(texts, show_progress_bar=True)
embeddings.shape
np.save("embeddings.npy", embeddings)
# Out:
# Batches:   0%|          | 0/1563 [00:00<?, ?it/s]
